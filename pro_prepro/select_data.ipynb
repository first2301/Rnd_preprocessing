# %%
import sqlite3
import pandas as pd
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.0' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# 프로그램 실행 전 (데이터 처리가 되지 않은 경우 에러 발생)
conn = sqlite3.connect('./database/database.db')
query = "SELECT * FROM TB_meta_info"  
df = pd.read_sql(query, conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py:2018, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2017 try:
# -> 2018     cur.execute(*args, **kwargs)
#    2019     return cur
#
# OperationalError: no such table: TB_meta_info
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /home/work/AI/image_prepro/select_data.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2Bvscode/home/work/AI/image_prepro/select_data.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> conn = sqlite3.connect('./database/database.db')
#       <a href='vscode-notebook-cell://ssh-remote%2Bvscode/home/work/AI/image_prepro/select_data.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> query = "SELECT * FROM TB_meta_info"
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bvscode/home/work/AI/image_prepro/select_data.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> df = pd.read_sql(query, conn)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py:564, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     561 pandas_sql = pandasSQL_builder(con)
#     563 if isinstance(pandas_sql, SQLiteDatabase):
# --> 564     return pandas_sql.read_query(
#     565         sql,
#     566         index_col=index_col,
#     567         params=params,
#     568         coerce_float=coerce_float,
#     569         parse_dates=parse_dates,
#     570         chunksize=chunksize,
#     571     )
#     573 try:
#     574     _is_table_name = pandas_sql.has_table(sql)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py:2078, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2066 def read_query(
#    2067     self,
#    2068     sql,
#    (...)
#    2074     dtype: DtypeArg | None = None,
#    2075 ) -> DataFrame | Iterator[DataFrame]:
#    2077     args = _convert_params(sql, params)
# -> 2078     cursor = self.execute(*args)
#    2079     columns = [col_desc[0] for col_desc in cursor.description]
#    2081     if chunksize is not None:
#
# File /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py:2030, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2027     raise ex from inner_exc
#    2029 ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2030 raise ex from exc
#
# DatabaseError: Execution failed on sql 'SELECT * FROM TB_meta_info': no such table: TB_meta_info

# %%
# 프로그램 실행 후 (데이터 처리가 완료된 경우 데이터 정상 출력)
conn = sqlite3.connect('./database/database.db')
query = "SELECT * FROM TB_meta_info"  
df = pd.read_sql(query, conn)

# %%
df
# Out:
#                                         full_path            folder  \
# 0       ./data/image/TS_1모래입자크기분류_009/2600156.png  TS_1모래입자크기분류_009
# 1       ./data/image/TS_1모래입자크기분류_008/2600156.png  TS_1모래입자크기분류_008
# 2       ./data/image/TS_1모래입자크기분류_009/2600192.png  TS_1모래입자크기분류_009
# 3       ./data/image/TS_1모래입자크기분류_009/2600181.png  TS_1모래입자크기분류_009
# 4       ./data/image/TS_1모래입자크기분류_009/2600211.png  TS_1모래입자크기분류_009
# ...                                           ...               ...
# 357306  ./data/image/TS_1모래입자크기분류_001/0530163.png  TS_1모래입자크기분류_001
# 357307  ./data/image/TS_1모래입자크기분류_001/0530175.png  TS_1모래입자크기분류_001
# 357308  ./data/image/TS_1모래입자크기분류_001/0530152.png  TS_1모래입자크기분류_001
# 357309  ./data/image/TS_1모래입자크기분류_001/0530231.png  TS_1모래입자크기분류_001
# 357310  ./data/image/TS_1모래입자크기분류_001/0530135.png  TS_1모래입자크기분류_001
#
#           file_name  file_size  width  height    밀도   흡수율   안전성  잔입자_통과량  \
# 0       2600156.png     562613   1920    1080  2.62  0.67  0.92    15.70
# 1       2600156.png     674816   1920    1080  2.62  0.67  0.92    15.70
# 2       2600192.png    1270181   1920    1080  2.62  0.67  0.92    15.70
# 3       2600181.png    1245979   1920    1080  2.62  0.67  0.92    15.70
# 4       2600211.png    1284082   1920    1080  2.62  0.67  0.92    15.70
# ...             ...        ...    ...     ...   ...   ...   ...      ...
# 357306  0530163.png    3217707   1920    1080  2.65  2.68  1.10     0.14
# 357307  0530175.png    3231272   1920    1080  2.65  2.68  1.10     0.14
# 357308  0530152.png    3107441   1920    1080  2.65  2.68  1.10     0.14
# 357309  0530231.png    3228419   1920    1080  2.65  2.68  1.10     0.14
# 357310  0530135.png    3285087   1920    1080  2.65  2.68  1.10     0.14
#
#        target_data
# 0               안정
# 1               안정
# 2               안정
# 3               안정
# 4               안정
# ...            ...
# 357306          위험
# 357307          위험
# 357308          위험
# 357309          위험
# 357310          위험
#
# [357311 rows x 11 columns]

# %%
# conn.close()
